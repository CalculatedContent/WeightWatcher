# %% [markdown]
# <a href="https://colab.research.google.com/github/CalculatedContent/WeightWatcher/blob/master/BuildWeightWatcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/CalculatedContent/WeightWatcher.git
# Out:
# Cloning into 'WeightWatcher'...
# remote: Enumerating objects: 2968, done.
# remote: Counting objects: 100% (2968/2968), done.
# remote: Compressing objects: 100% (1008/1008), done.
# remote: Total 2968 (delta 1971), reused 2946 (delta 1954), pack-reused 0
# Receiving objects: 100% (2968/2968), 95.12 MiB | 40.52 MiB/s, done.
# Resolving deltas: 100% (1971/1971), done.

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 83.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 107.8 MB/s eta 0:00:00
# ...

# %%
# %cd WeightWatcher
# !python setup.py build install
# Out:
# /content/WeightWatcher
# /usr/local/lib/python3.8/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/weightwatcher
# copying weightwatcher/weightwatcher.py -> build/lib/weightwatcher
# copying weightwatcher/__init__.py -> build/lib/weightwatcher
# copying weightwatcher/constants.py -> build/lib/weightwatcher
# copying weightwatcher/RMT_Util.py -> build/lib/weightwatcher
# copying weightwatcher/__main__.py -> build/lib/weightwatcher
# running egg_info
# creating weightwatcher.egg-info
# writing weightwatcher.egg-info/PKG-INFO
# writing dependency_links to weightwatcher.egg-info/dependency_links.txt
# writing entry points to weightwatcher.egg-info/entry_points.txt
# writing requirements to weightwatcher.egg-info/requires.txt
# ...

# %%
# !python -m unittest -k Test_ValidParams
# Out:
# -------------------------------------
# In Test_ValidParams: test_invalid_PL_package_settings
# CRITICAL:weightwatcher:xmax=force not available if using pl_package=ww
# CRITICAL:weightwatcher:pl_package only supports PowerLaw fits, but fit=TPL
# CRITICAL:weightwatcher:pl_package only supports PowerLaw fits, but fit=E_TPL
# CRITICAL:weightwatcher:pl_package only supports PowerLaw fits, but fit=truncated_power_law
# CRITICAL:weightwatcher:xmax can not be 0
# WARNING:weightwatcher:Unknown how to fix fingers True, deactivating
# .
# -------------------------------------
# In Test_ValidParams: test_valid_params
# WARNING:weightwatcher:fix_fingers ignores xmax = None
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 0.470s
#
# OK

# %%
# !python -m unittest -k Test_KerasLayers
# Out:
# -------------------------------------
# In Test_KerasLayers: test_keras_layer_constructor
# .
# -------------------------------------
# In Test_KerasLayers: test_replace_weights_and_biases
# .
# -------------------------------------
# In Test_KerasLayers: test_replace_weights_only
# .
# -------------------------------------
# In Test_KerasLayers: test_ww_layer_attributes
# the longname is None
# .
# -------------------------------------
# In Test_KerasLayers: test_ww_layer_iterator
# .
# ----------------------------------------------------------------------
# Ran 5 tests in 15.161s
#
# OK

# %%
# !python -m unittest -k Test_PyTorchLayers
# Out:
# -------------------------------------
# In Test_PyTorchLayers: test_pytorch_layer_constructor
# .
# -------------------------------------
# In Test_PyTorchLayers: test_replace_weights_and_biases
# .
# -------------------------------------
# In Test_PyTorchLayers: test_replace_weights_only
# .
# -------------------------------------
# In Test_PyTorchLayers: test_ww_layer_attributes
# the longname is fc
# .
# -------------------------------------
# In Test_PyTorchLayers: test_ww_layer_iterator
# .
# ----------------------------------------------------------------------
# Ran 5 tests in 1.789s
#
# OK

# %%
# !python -m unittest -k Test_PyStateDictLayers
# Out:
# -------------------------------------
# In Test_PyStateDictLayers: test_pytorch_layer_constructor
# ...
# .
# -------------------------------------
# In Test_PyStateDictLayers: test_replace_weights_and_biases
# WWLayer 1  conv1 CONV2D  skipped False
# WWLayer 3  layer1.0.conv1 CONV2D  skipped False
# WWLayer 5  layer1.0.conv2 CONV2D  skipped False
# WWLayer 7  layer1.1.conv1 CONV2D  skipped False
# WWLayer 9  layer1.1.conv2 CONV2D  skipped False
# WWLayer 11  layer2.0.conv1 CONV2D  skipped False
# WWLayer 13  layer2.0.conv2 CONV2D  skipped False
# WWLayer 15  layer2.0.downsample.0 CONV2D  skipped False
# WWLayer 17  layer2.1.conv1 CONV2D  skipped False
# WWLayer 19  layer2.1.conv2 CONV2D  skipped False
# WWLayer 21  layer3.0.conv1 CONV2D  skipped False
# WWLayer 23  layer3.0.conv2 CONV2D  skipped False
# WWLayer 25  layer3.0.downsample.0 CONV2D  skipped False
# WWLayer 27  layer3.1.conv1 CONV2D  skipped False
# WWLayer 29  layer3.1.conv2 CONV2D  skipped False
# ...

# %%
# !python -m unittest -k Test_VGG11_noModel
# Out:
# -------------------------------------
# In Test_VGG11_noModel: test_analyze_columns_no_model
# Index(['layer_id', 'name', 'D', 'Lambda', 'M', 'N', 'Q', 'alpha',
#        'alpha_weighted', 'best_fit', 'entropy', 'fit_entropy', 'has_esd',
#        'lambda_max', 'layer_type', 'log_alpha_norm', 'log_norm',
#        'log_spectral_norm', 'longname', 'matrix_rank', 'norm', 'num_evals',
#        'num_fingers', 'num_pl_spikes', 'rank_loss', 'rf', 'sigma',
#        'spectral_norm', 'stable_rank', 'sv_max', 'warning', 'weak_rank_loss',
#        'xmax', 'xmin'],
#       dtype='object')
# .
# -------------------------------------
# In Test_VGG11_noModel: test_basic_columns_no_model
#     layer_id    name     M  ...      longname  num_evals rf
# 0          2  Conv2d     3  ...    features.0         27  9
# 1          5  Conv2d    64  ...    features.3        576  9
# 2          8  Conv2d   128  ...    features.6       1152  9
# 3         10  Conv2d   256  ...    features.8       2304  9
# ...

# %%
# !python -m unittest -k Test_VGG11_Distances
# Out:
# -------------------------------------
# In Test_VGG11_Distances: test_CKA_distances
# ====== pool=True ========
#          method    name   delta_W  delta_b     M      N  b_shape      longname
# layer_id
# 5           cka  Conv2d  1.000000      0.0    64    128  unknown    features.3
# 8           cka  Conv2d  1.000000      0.0   128    256  unknown    features.6
# 10          cka  Conv2d  1.000000      0.0   256    256  unknown    features.8
# 13          cka  Conv2d  1.000000      0.0   256    512  unknown   features.11
# 15          cka  Conv2d  1.000000      0.0   512    512  unknown   features.13
# 18          cka  Conv2d  1.000000      0.0   512    512  unknown   features.16
# 20          cka  Conv2d  1.000000      0.0   512    512  unknown   features.18
# 25          cka  Linear  0.988792      0.0  4096  25088  unknown  classifier.0
# 28          cka  Linear  1.000003      0.0  4096   4096  unknown  classifier.3
# ...

# %%
# !python -m unittest -k Test_Albert
# Out:
# -------------------------------------
# In Test_Albert: test_albert_availbla
# Some weights of the model checkpoint at albert-xxlarge-v2 were not used when initializing AlbertModel: ['predictions.dense.bias', 'predictions.dense.weight', 'predictions.LayerNorm.bias', 'predictions.bias', 'predictions.decoder.weight', 'predictions.LayerNorm.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#    layer_id    name  ...  num_evals  rf
# 0        17  Linear  ...       4096   1
#
# [1 rows x 9 columns]
# .
# -------------------------------------
# ...

# %%
# !python -m unittest -k Test_VGG11_Base
# Out:
# -------------------------------------
# In Test_VGG11_Base: test_ESD_model_set
#     layer_id    name     M  ...      longname  num_evals rf
# 0          2  Conv2d     3  ...    features.0         27  9
# 1          5  Conv2d    64  ...    features.3        576  9
# 2          8  Conv2d   128  ...    features.6       1152  9
# 3         10  Conv2d   256  ...    features.8       2304  9
# 4         13  Conv2d   256  ...   features.11       2304  9
# 5         15  Conv2d   512  ...   features.13       4608  9
# 6         18  Conv2d   512  ...   features.16       4608  9
# 7         20  Conv2d   512  ...   features.18       4608  9
# 8         25  Linear  4096  ...  classifier.0       4096  1
# 9         28  Linear  4096  ...  classifier.3       4096  1
# 10        31  Linear  1000  ...  classifier.6       1000  1
#
# [11 rows x 9 columns]
# 4096
# 4096
# max esd before 60.278518503997944
# max esd after 60.278518503997944
# .
# -------------------------------------
# ...

# %%
# !python -m unittest -k Test_VGG11_StateDict
# Out:
# -------------------------------------
# In Test_VGG11_StateDict: test_ESD_model_set
#     layer_id          name     M  ...      longname  num_evals rf
# 0          1    features.0     3  ...    features.0         27  9
# 1          2    features.3    64  ...    features.3        576  9
# 2          3    features.6   128  ...    features.6       1152  9
# 3          4    features.8   256  ...    features.8       2304  9
# 4          5   features.11   256  ...   features.11       2304  9
# 5          6   features.13   512  ...   features.13       4608  9
# 6          7   features.16   512  ...   features.16       4608  9
# 7          8   features.18   512  ...   features.18       4608  9
# 8          9  classifier.0  4096  ...  classifier.0       4096  1
# 9         10  classifier.3  4096  ...  classifier.3       4096  1
# 10        11  classifier.6  1000  ...  classifier.6       1000  1
#
# [11 rows x 9 columns]
# 4096
# 4096
# max esd before 60.278518503997944
# ...

# %%
# !python -m unittest -k Test_VGG11_Alpha_w_PowerLawFit
# Out:
# -------------------------------------
# In Test_VGG11_Alpha_w_PowerLawFit: test_compute_alphas
# .
# -------------------------------------
# In Test_VGG11_Alpha_w_PowerLawFit: test_extended_truncated_power_law_fit
# WARNING:weightwatcher:E-TPL and fix_fingers can not both be set
# ERROR:weightwatcher:Error, params not valid:
#  {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'plot': False, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'kernel_fft': False, 'ww2x': False, 'pool': True, 'vectors': False, 'smooth': None, 'stacked': False, 'svd_method': 'fast', 'fix_fingers': False, 'fit': 'E_TPL', 'sparsify': True, 'detX': False, 'mp_fit': False, 'min_evals': 50, 'max_evals': 10000, 'max_N': 10, 'tolerance': 1e-06, 'layer_ids_start': 0, 'add_biases': False, 'pl_package': 'powerlaw', 'xmax': 'force', 'glorot_fit': False, False: False, 'layers': [25], 'xmin_max': None}
# ...

# %%
# !python -m unittest -k Test_VGG11_Alpha_w_WWFit
# Out:
# -------------------------------------
# In Test_VGG11_Alpha_w_WWFit: test_WWFit_available
# .
# -------------------------------------
# In Test_VGG11_Alpha_w_WWFit: test_compute_alphas
# .
# -------------------------------------
# In Test_VGG11_Alpha_w_WWFit: test_fix_fingers_clip_xmax
# WARNING:weightwatcher:fix_fingers ignores xmax = None
# WARNING:weightwatcher:fix_fingers ignores xmax = None
# .
# -------------------------------------
# In Test_VGG11_Alpha_w_WWFit: test_fix_fingers_clip_xmax_w_Force
# WARNING:weightwatcher:clipped fit may be spurious, new alpha found: 12.55
# .
# -------------------------------------
# In Test_VGG11_Alpha_w_WWFit: test_kernel_fft
# WARNING:weightwatcher:KERNEL_FFT option not currently supported, may be deprecated
# ERROR:weightwatcher:Error, params not valid:
# ...

# %%
# !python -m unittest -k Test_VGG11_StateDict_Alpha_w_WWFit
# Out:
# -------------------------------------
# In Test_VGG11_StateDict_Alpha_w_WWFit: test_WWFit_available
# .
# -------------------------------------
# In Test_VGG11_StateDict_Alpha_w_WWFit: test_compute_alphas
# .
# -------------------------------------
# In Test_VGG11_StateDict_Alpha_w_WWFit: test_fix_fingers_clip_xmax
# WARNING:weightwatcher:fix_fingers ignores xmax = None
# WARNING:weightwatcher:fix_fingers ignores xmax = None
# .
# -------------------------------------
# In Test_VGG11_StateDict_Alpha_w_WWFit: test_fix_fingers_clip_xmax_w_Force
# WARNING:weightwatcher:clipped fit may be spurious, new alpha found: 12.55
# .
# -------------------------------------
# In Test_VGG11_StateDict_Alpha_w_WWFit: test_kernel_fft
# WARNING:weightwatcher:KERNEL_FFT option not currently supported, may be deprecated
# ERROR:weightwatcher:Error, params not valid:
# ...

# %%
# !python -m unittest -k Test_Keras
# Out:
# -------------------------------------
# In Test_Keras: test_N_ge_M
# .
# -------------------------------------
# In Test_Keras: test_basic_columns
# .
# -------------------------------------
# In Test_Keras: test_channels_first
# .
# -------------------------------------
# In Test_Keras: test_kayer_ids
#     layer_id          name     M  ...  longname  num_evals rf
# 0          1  block1_conv1     3  ...      None         27  9
# 1          2  block1_conv2    64  ...      None        576  9
# 2          4  block2_conv1    64  ...      None        576  9
# 3          5  block2_conv2   128  ...      None       1152  9
# 4          7  block3_conv1   128  ...      None       1152  9
# 5          8  block3_conv2   256  ...      None       2304  9
# 6          9  block3_conv3   256  ...      None       2304  9
# 7         11  block4_conv1   256  ...      None       2304  9
# 8         12  block4_conv2   512  ...      None       4608  9
# ...

# %%
# !python -m unittest -k Test_ResNet
# Out:
# ..
# -------------------------------------
# In Test_ResNet_Models: test_num_evals
# .
# -------------------------------------
# In Test_ResNet_Models: test_weight_watcher
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 2.085s
#
# OK

# %%
# !python -m unittest -k Test_ResNet_Models
# Out:
# -------------------------------------
# In Test_ResNet_Models: test_num_evals
# .
# -------------------------------------
# In Test_ResNet_Models: test_weight_watcher
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 1.257s
#
# OK

# %%
# !python -m unittest -k Test_RMT_Util
# Out:
# -------------------------------------
# In Test_RMT_Util: test_combine_weights_and_biases
# .
# -------------------------------------
# In Test_RMT_Util: test_detX_constraint
# .
# -------------------------------------
# In Test_RMT_Util: test_line_entropy
# .
# -------------------------------------
# In Test_RMT_Util: test_permute_matrix
# .
# -------------------------------------
# In Test_RMT_Util: test_vector_entropy
# .
# ----------------------------------------------------------------------
# Ran 5 tests in 0.910s
#
# OK

# %%
# !python -m unittest -k Test_Vector_Metrics
# Out:
# -------------------------------------
# In Test_Vector_Metrics: test_valid_vectors
# .
# -------------------------------------
# In Test_Vector_Metrics: test_vector_iterator
# v=  [0 1 2 3 4]
# v=  [0 1 2 3 4]
# v=  [0 1 2 3 4]
# v=  [0 1 2 3 4]
# v=  [0 1 2 3 4]
# v=  [0 1 2 3 4]
# .
# -------------------------------------
# In Test_Vector_Metrics: test_vector_metrics
# /darda/WeightWatcher/weightwatcher/weightwatcher.py:2319: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df.loc[iv] = None
#    length   entropy  ...  participation_ratio  discete_entropy
# 0     5.0  0.025796  ...             1.262728         1.609438
#
# [1 rows x 6 columns]
# .
# ----------------------------------------------------------------------
# Ran 3 tests in 0.603s
#
# OK

# %%
# !python -m unittest -k Test_Distances
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK

# %%
# !python -m unittest -k Test_PyTorchSVD
# Out:
# -------------------------------------
# In Test_PyTorchSVD: test_bad_methods
# .
# -------------------------------------
# In Test_PyTorchSVD: test_torch_availability
# torch is available and cuda is available
# .
# -------------------------------------
# In Test_PyTorchSVD: test_torch_linalg
# .
# -------------------------------------
# In Test_PyTorchSVD: test_torch_svd
# PyTorch (fast): 7.375410318374634s
# SciPy (accurate): 38.66134762763977s
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 51.293s
#
# OK

# %%
# !python -m unittest -k Test_PowerLaw
# Out:
# -------------------------------------
# In Test_PowerLaw: test_PL_speed
# Calculating best minimal value for power law fit
# WW powerlaw time is 5.97x faster with M = 512
# .
# -------------------------------------
# In Test_PowerLaw: test_fit_attributes
# .
# -------------------------------------
# In Test_PowerLaw: test_fit_clipped_powerlaw
# .
# -------------------------------------
# In Test_PowerLaw: test_ww_power_law_fit_directly
# .
# ----------------------------------------------------------------------
# Ran 4 tests in 5.275s
#
# OK

# %%
# !python -m unittest -k Test_Plots
# Out:
# -------------------------------------
# In Test_Plots: testPlots
# .
# ----------------------------------------------------------------------
# Ran 1 test in 7.875s
#
# OK

# %%
# !python -m unittest -k Test_Pandas
# Out:
# -------------------------------------
# In Test_Pandas: test_column_names_analyze
# .
# -------------------------------------
# In Test_Pandas: test_column_names_analyze_detX
# /home/hman/anaconda3/envs/kaggle/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# .
# -------------------------------------
# In Test_Pandas: test_column_names_analyze_intra
# .
# -------------------------------------
# In Test_Pandas: test_column_names_analyze_mp_fit
# .
# -------------------------------------
# In Test_Pandas: test_column_names_analyze_randomize
# .
# -------------------------------------
# In Test_Pandas: test_column_names_describe_basic
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 8.132s
#
# OK

# %% [markdown]
# ### Deploy to test pypi

# %%
# !python -m pip install --upgrade setuptools wheel twine
# !python setup.py sdist bdist_wheel
# !twine check dist/*
# !ls dist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 KB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 76.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: setuptools
# ...

# %%
#!twine upload --repository testpypi dist/*

# %%
charles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-48a517fe9889> in <module>
# ----> 1 charles
#
# NameError: name 'charles' is not defined
