# %% [markdown]
# # WeightWatcher - SVDSmoothing
#
# ### Example of SVDSmoothing using the VGG11 model

# %%
# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
import numpy as np
import pandas as pd

import tensorflow
import torchvision.models as models
from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import WeightWatcher
#
# set custom Logging at WARN Level

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %%
import weightwatcher as ww
logger = logging.getLogger(ww.__name__)
logger.setLevel(logging.DEBUG)

ww.__version__
# Out:
# '0.4.9'

# %% [markdown]
# ### ONNX Example

# %%
import onnx
from onnx import numpy_helper

# %%
model = onnx.load("example.onnx")
watcher = ww.WeightWatcher(model=model)
watcher.describe(channels='last')
# Out:
# INFO:weightwatcher:
#
# python      version 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]
# numpy       version 1.18.5
# tensforflow version 2.3.0
# keras       version 2.4.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': 'last', 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': []}
# DEBUG:weightwatcher:FRAMEWORKS: KERAS = 4  PYTORCH = 2 ONNX = 8 UNKNOWN = 1
# DEBUG:weightwatcher:FIRST = 2  LAST = 4 UNKNOWN = 1
# DEBUG:weightwatcher:MODEL ITERATOR, framework = 8, channels = 4
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x1 (NxM), 1x1 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=1 rf= 1 channels = 4
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 0 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (1, 1, 1, 1)  max size None
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 8x1 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=8 M=1 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 8 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 1 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (8, 1, 3, 3)  max size None
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 2  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 2 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 3  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 3 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 4  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 4 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 5  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 5 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 6  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 6 None type 1 unknown
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 16x8 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=16 M=8 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 16 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 7 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (16, 8, 3, 3)  max size None
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 8  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 8 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 9  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 9 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 10  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 10 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 11  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 11 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 12  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 12 None type 1 unknown
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x16 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=16 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 13 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (32, 16, 3, 3)  max size None
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 14  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 14 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 15  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 15 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 16  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 16 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 17  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 17 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 18  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 18 None type 1 unknown
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x32 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=32 rf= 9 channels = 4
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 19 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (32, 32, 3, 3)  max size None
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 20  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 20 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 21  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 21 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 22  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 22 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 23  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 23 None type 1 unknown
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 24  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 24 None type 1 unknown
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x32 (NxM), 7x7 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=32 rf= 49 channels = 4
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:LAYER TYPE: 25 16  layer type <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:weights shape : (1, 32, 7, 7)  max size None
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [1]
# INFO:weightwatcher:Layer id 26  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:layer not supported: Layer 26 None type 1 unknown
#   layer_id  name     M     N         layer_type  num_evals    rf
# 0        0  None   1.0   1.0  LAYER_TYPE.CONV2D        1.0   1.0
# 1        1  None   1.0   8.0  LAYER_TYPE.CONV2D        9.0   9.0
# 2        7  None   8.0  16.0  LAYER_TYPE.CONV2D       72.0   9.0
# 3       13  None  16.0  32.0  LAYER_TYPE.CONV2D      144.0   9.0
# 4       19  None  32.0  32.0  LAYER_TYPE.CONV2D      288.0   9.0
# 5       25  None  32.0   1.0  LAYER_TYPE.CONV2D     1568.0  49.0

# %%
watcher.analyze()

# %%
watcher.analyze(layers=[1,7,13,19])
# Out:
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [1, 7, 13, 19]}
# DEBUG:weightwatcher:FRAMEWORKS: KERAS = 4  PYTORCH = 2 ONNX = 8 UNKNOWN = 1
# DEBUG:weightwatcher:FIRST = 2  LAST = 4 UNKNOWN = 1
# DEBUG:weightwatcher:MODEL ITERATOR, framework = 8, channels = 4
# INFO:weightwatcher:Filtering layer by id 1
# INFO:weightwatcher:Filtering layer by id 7
# INFO:weightwatcher:Filtering layer by id 13
# INFO:weightwatcher:Filtering layer by id 19
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x1 (NxM), 1x1 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=1 rf= 1 channels = 4
# INFO:weightwatcher:skipping layer 0 None by id
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:Layer 0 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 8x1 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=8 M=1 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 1 None by id
# DEBUG:weightwatcher:layer_supported  N 8 max evals None
# INFO:weightwatcher:LAYER: 1 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:apply ESD  on Layer 1 None
# DEBUG:weightwatcher:running SVD on Layer 1 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [1, 7, 13, 19]}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:Running full SVD:  W.shape=(8, 1)  n_comp = 1
# DEBUG:weightwatcher:fitting power law on 9 eigenvalues
# DEBUG:weightwatcher:finding best distribution for fit
# Assuming nested distributions
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 2  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 2 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 2 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 3  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 3 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 3 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 4  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 4 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 4 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 5  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 5 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 5 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 6  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 6 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 6 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 16x8 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=16 M=8 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 7 None by id
# DEBUG:weightwatcher:layer_supported  N 16 max evals None
# INFO:weightwatcher:LAYER: 7 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:apply ESD  on Layer 7 None
# DEBUG:weightwatcher:running SVD on Layer 7 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [1, 7, 13, 19]}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:Running full SVD:  W.shape=(16, 8)  n_comp = 8
# DEBUG:weightwatcher:fitting power law on 72 eigenvalues
# DEBUG:weightwatcher:finding best distribution for fit
# Assuming nested distributions
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 8  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 8 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 8 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 9  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 9 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 9 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 10  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 10 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 10 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 11  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 11 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 11 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 12  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 12 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 12 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x16 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=16 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 13 None by id
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# INFO:weightwatcher:LAYER: 13 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:apply ESD  on Layer 13 None
# DEBUG:weightwatcher:running SVD on Layer 13 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [1, 7, 13, 19]}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 16)  n_comp = 16
# DEBUG:weightwatcher:fitting power law on 144 eigenvalues
# DEBUG:weightwatcher:finding best distribution for fit
# Assuming nested distributions
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 14  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 14 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 14 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 15  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 15 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 15 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 16  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 16 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 16 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 17  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 17 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 17 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 18  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 18 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 18 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x32 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=32 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 19 None by id
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# INFO:weightwatcher:LAYER: 19 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# DEBUG:weightwatcher:apply ESD  on Layer 19 None
# DEBUG:weightwatcher:running SVD on Layer 19 None
# DEBUG:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [1, 7, 13, 19]}
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:Running full SVD:  W.shape=(32, 32)  n_comp = 32
# DEBUG:weightwatcher:fitting power law on 288 eigenvalues
# DEBUG:weightwatcher:finding best distribution for fit
# Assuming nested distributions
# INFO:weightwatcher:compare dist=lognormal R=0.2056875284453196 p=0.8370350011211934
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 20  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 20 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 20 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 21  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 21 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 21 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 22  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 22 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 22 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 23  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 23 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 23 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 24  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 24 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 24 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x32 (NxM), 7x7 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=32 rf= 49 channels = 4
# INFO:weightwatcher:skipping layer 25 None by id
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:Layer 25 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [1]
# INFO:weightwatcher:Layer id 26  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 26 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 26 None is skipped
#   layer_id  name         D     M     N     alpha  alpha_weighted  \
# 0        1  None  0.259648   1.0   8.0  3.031012        0.802709
# 1        7  None  0.131396   8.0  16.0  6.060119        0.213827
# 2       13  None  0.142098  16.0  32.0  2.505632       -0.042734
# 3       19  None  0.155170  32.0  32.0  2.851987       -0.502200
#
#               best_fit   entropy  has_esd  ...  num_evals num_pl_spikes  \
# 0  truncated_power_law  0.935927      1.0  ...        9.0           7.0
# 1  truncated_power_law  0.901188      1.0  ...       72.0           9.0
# 2  truncated_power_law  0.913796      1.0  ...      144.0          62.0
# 3            lognormal  0.890765      1.0  ...      288.0          78.0
#
#    rank_loss   rf     sigma  spectral_norm  stable_rank    sv_max      xmax  \
# 0        0.0  9.0  0.767650       1.840061     4.396896  1.356488  1.840061
# 1        0.0  9.0  1.686706       1.084637    15.190852  1.041459  1.084637
# 2        0.0  9.0  0.191215       0.961490    27.225922  0.980556  0.961490
# 3        0.0  9.0  0.209696       0.666672    48.606331  0.816500  0.666672
#
#        xmin
# 0  0.577397
# 1  0.566951
# 2  0.153311
# 3  0.160011
#
# [4 rows x 27 columns]

# %%
watcher = ww.WeightWatcher(model=model)
smoothed_model = watcher.SVDSmoothing(layers=[7,13,19])
# Out:
# INFO:weightwatcher:
#
# python      version 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]
# numpy       version 1.18.5
# tensforflow version 2.3.0
# keras       version 2.4.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'ww2x': False, 'layers': [7, 13, 19], 'percent': 0.2}
# DEBUG:weightwatcher:FRAMEWORKS: KERAS = 4  PYTORCH = 2 ONNX = 8 UNKNOWN = 1
# DEBUG:weightwatcher:FIRST = 2  LAST = 4 UNKNOWN = 1
# DEBUG:weightwatcher:MODEL ITERATOR, framework = 8, channels = 4
# INFO:weightwatcher:Filtering layer by id 7
# INFO:weightwatcher:Filtering layer by id 13
# INFO:weightwatcher:Filtering layer by id 19
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x1 (NxM), 1x1 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=1 rf= 1 channels = 4
# INFO:weightwatcher:skipping layer 0 None by id
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:Layer 0 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 8x1 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=8 M=1 rf= 9 channels = 4
# INFO:weightwatcher:skipping layer 1 None by id
# DEBUG:weightwatcher:layer_supported  N 8 max evals None
# DEBUG:weightwatcher:Layer 1 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 2  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 2 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 2 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 3  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 3 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 3 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 4  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 4 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 4 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 5  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 5 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 5 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [8]
# INFO:weightwatcher:Layer id 6  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 6 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 6 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 16x8 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=16 M=8 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 7 None by id
# DEBUG:weightwatcher:layer_supported  N 16 max evals None
# INFO:weightwatcher:LAYER: 7 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:apply truncated SVD on Layer 7 None, keeping 0.20% percent , or ncomp=1 out of 8. of the singular vectors
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:smoothed W (16, 8) -> (16, 8) n_comp=1
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 8  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 8 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 8 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 9  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 9 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 9 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 10  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 10 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 10 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 11  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 11 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 11 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [16]
# INFO:weightwatcher:Layer id 12  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 12 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 12 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x16 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=16 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 13 None by id
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# INFO:weightwatcher:LAYER: 13 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:apply truncated SVD on Layer 13 None, keeping 0.20% percent , or ncomp=3 out of 16. of the singular vectors
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:smoothed W (32, 16) -> (32, 16) n_comp=3
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 14  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 14 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 14 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 15  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 15 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 15 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 16  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 16 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 16 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 17  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 17 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 17 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 18  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 18 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 18 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 32x32 (NxM), 3x3 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=32 M=32 rf= 9 channels = 4
# INFO:weightwatcher:keeping layer 19 None by id
# DEBUG:weightwatcher:layer_supported  N 32 max evals None
# INFO:weightwatcher:LAYER: 19 16  : <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:apply truncated SVD on Layer 19 None, keeping 0.20% percent , or ncomp=6 out of 32. of the singular vectors
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:smoothed W (32, 32) -> (32, 32) n_comp=6
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 20  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 20 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 20 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 21  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 21 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 21 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 22  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 22 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 22 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 23  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 23 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 23 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [32]
# INFO:weightwatcher:Layer id 24  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 24 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 24 None is skipped
# DEBUG:weightwatcher:conv2D_Wmats
# DEBUG:weightwatcher:Channels Last tensor shape: 1x32 (NxM), 7x7 (i,j)
# DEBUG:weightwatcher:get_conv2D_Wmats N=1 M=32 rf= 49 channels = 4
# INFO:weightwatcher:skipping layer 25 None by id
# DEBUG:weightwatcher:layer_supported  N 1 max evals None
# DEBUG:weightwatcher:Layer 25 None is skipped
# DEBUG:weightwatcher:Unsupported ONNX Layer, dims = [1]
# INFO:weightwatcher:Layer id 26  unknown type 1 layer  <class 'weightwatcher.weightwatcher.ONNXLayer'>
# INFO:weightwatcher:skipping layer 26 None by id
# DEBUG:weightwatcher:layer_supported  N 0 max evals None
# DEBUG:weightwatcher:Layer 26 None is skipped
# INFO:weightwatcher:Returning smoothed model
