# %% [markdown]
# # WeightWatcher - Test
#
# Quick test to ensure version is working

# %%
# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext watermark
# %watermark
# Out:
# 2021-04-01T07:27:45-07:00
#
# CPython 3.8.5
# IPython 7.18.1
#
# compiler   : Clang 10.0.0
# system     : Darwin
# release    : 17.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 12
# interpreter: 64bit

# %% [markdown]
# ### Import WeightWatcher
#
# set custom Logging at WARN Level

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.WARN)

import weightwatcher as ww
import torchvision.models as models

ww.__version__
# Out:
# '0.4.2'

# %% [markdown]
# ###  Helper Notebook to make Plots

# %%
import import_ipynb
import ModelPlots as MP
# Out:
# importing Jupyter notebook from ModelPlots.ipynb

# %% [markdown]
# ### Create all models now
#
# Pick colors from https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %%
model = models.vgg11(pretrained=True)

# %% [markdown]
# ### Run WeightWatcher, collect summary and details (as dataframes) for all models

# %%
watcher = ww.WeightWatcher(model=model)
results = watcher.analyze(plot=True)
# Out:
# INFO:weightwatcher:
#
# python      version 3.8.5 (default, Sep  4 2020, 02:22:02)
# [Clang 10.0.0 ]
# numpy       version 1.18.5
# tensforflow version 2.3.0
# keras       version 2.4.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savefig': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': False, 'ww2x': False}
# INFO:weightwatcher:LAYER: 2 8  : <class 'torch.nn.modules.conv.Conv2d'>
# INFO:weightwatcher:LAYER: 5 8  : <class 'torch.nn.modules.conv.Conv2d'>
# INFO:weightwatcher:LAYER: 8 8  : <class 'torch.nn.modules.conv.Conv2d'>
# INFO:weightwatcher:LAYER: 10 8  : <class 'torch.nn.modules.conv.Conv2d'>
# INFO:weightwatcher:LAYER: 13 8  : <class 'torch.nn.modules.conv.Conv2d'>
# INFO:weightwatcher:LAYER: 15 8  : <class 'torch.nn.modules.conv.Conv2d'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ff2a9aaabcfc> in <module>
#       1 watcher = ww.WeightWatcher(model=model)
# ----> 2 results = watcher.analyze(plot=True)
#       3
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/weightwatcher-0.4.2-py3.8.egg/weightwatcher/weightwatcher.py in analyze(self, model, layers, min_evals, max_evals, min_size, max_size, normalize, glorot_fix, plot, randomize, savefig, mp_fit, conv2d_fft, conv2d_norm, fit_bulk, ww2x)
#     987
#     988                 if ww_layer.evals is not None:
# --> 989                     self.apply_fit_powerlaw(ww_layer, params)
#     990                     if params['mp_fit']:
#     991                         logger.info("MP Fitting Layer: {} {} ".format(ww_layer.layer_id, ww_layer.name))
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/weightwatcher-0.4.2-py3.8.egg/weightwatcher/weightwatcher.py in apply_fit_powerlaw(self, ww_layer, params)
#     882
#     883         layer_name = "Layer {}".format(layer_id)
# --> 884         alpha, xmin, xmax, D, sigma, num_pl_spikes = self.fit_powerlaw(evals, xmin=xmin, xmax=xmax, plot=plot, layer_name=layer_name, \
#     885                                                                            sample=sample, sample_size=sample_size, savefig=savefig)
#     886
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/weightwatcher-0.4.2-py3.8.egg/weightwatcher/weightwatcher.py in fit_powerlaw(self, evals, xmin, xmax, plot, layer_name, sample, sample_size, savefig)
#    1312
#    1313         if xmin == XMAX.AUTO  or xmin is None:
# -> 1314             fit = powerlaw.Fit(evals, xmax=xmax, verbose=False)
#    1315         elif xmin == XMAX.PEAK :
#    1316             nz_evals = evals[evals > 0.0]
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in __init__(self, data, discrete, xmin, xmax, verbose, fit_method, estimate_discrete, discrete_approximation, sigma_threshold, parameter_range, fit_optimizer, xmin_distance, **kwargs)
#     135             if verbose:
#     136                 print("Calculating best minimal value for power law fit", file=sys.stderr)
# --> 137             self.find_xmin()
#     138
#     139         self.data = self.data[self.data>=self.xmin]
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in find_xmin(self, xmin_distance)
#     234             return getattr(pl, xmin_distance), pl.alpha, pl.sigma, pl.in_range()
#     235
# --> 236         fits = asarray(list(map(fit_function, xmins)))
#     237         # logging.warning(fits.shape)
#     238         setattr(self, xmin_distance+'s', fits[:,0])
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in fit_function(xmin)
#     224
#     225         def fit_function(xmin):
# --> 226             pl = Power_Law(xmin=xmin,
#     227                            xmax=self.xmax,
#     228                            discrete=self.discrete,
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in __init__(self, estimate_discrete, **kwargs)
#    1111     def __init__(self, estimate_discrete=True, **kwargs):
#    1112         self.estimate_discrete = estimate_discrete
# -> 1113         Distribution.__init__(self, **kwargs)
#    1114
#    1115     def parameters(self, params):
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in __init__(self, xmin, xmax, discrete, fit_method, data, parameters, parameter_range, initial_parameters, discrete_approximation, parent_Fit, **kwargs)
#     608
#     609         if (data is not None) and not (parameter_range and self.parent_Fit):
# --> 610             self.fit(data)
#     611
#     612
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in fit(self, data)
#    1149             self.KS(data)
#    1150         else:
# -> 1151             Distribution.fit(self, data, suppress_output=True)
#    1152
#    1153         if not self.in_range():
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in fit(self, data, suppress_output)
#     631         from scipy.optimize import fmin
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
# --> 633             fmin(
#     634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     441             'initial_simplex': initial_simplex}
#     442
# --> 443     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     444     if full_output:
#     445         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     631                     # Perform an inside contraction
#     632                     xcc = (1 - psi) * xbar + psi * sim[-1]
# --> 633                     fxcc = func(xcc)
#     634
#     635                     if fxcc < fsim[-1]:
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in <lambda>(params)
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
#     633             fmin(
# --> 634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in fit_function(params)
#     623             def fit_function(params):
#     624                 self.parameters(params)
# --> 625                 return -sum(self.loglikelihoods(data))
#     626         elif self.fit_method=='KS':
#     627             def fit_function(params):
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in loglikelihoods(self, data)
#     952         """
#     953         from numpy import log
# --> 954         return log(self.likelihoods(data))
#     955
#     956     def plot_ccdf(self, data=None, ax=None, survival=True, **kwargs):
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in likelihoods(self, data)
#     944         Another name for the probabilities or probability density function.
#     945         """
# --> 946         return self.pdf(data)
#     947
#     948     def loglikelihoods(self, data):
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in pdf(self, data)
#     813         if data is None and hasattr(self, 'parent_Fit'):
#     814             data = self.parent_Fit.data
# --> 815         data = trim_to_range(data, xmin=self.xmin, xmax=self.xmax)
#     816         n = len(data)
#     817         from sys import float_info
#
# ~/anaconda3/envs/ww0.4/lib/python3.8/site-packages/powerlaw.py in trim_to_range(data, xmin, xmax, **kwargs)
#    1915     data = asarray(data)
#    1916     if xmin:
# -> 1917         data = data[data>=xmin]
#    1918     if xmax:
#    1919         data = data[data<=xmax]
#
# KeyboardInterrupt:

# %%
# !pwd
# Out:
# /Users/charleshmartin/work/ww-trends-2020
