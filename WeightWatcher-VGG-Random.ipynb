# %% [markdown]
# # WeightWatcher - VGG - Random

# %%
# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import WeightWatcher
#
# set custom Logging at WARN Level

# %%
import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

import weightwatcher as ww
import torchvision.models as models

ww.__version__
# Out:
# '0.5'

# %% [markdown]
# ###  Helper Notebook to make Plots

# %%
import import_ipynb
import ModelPlots as MP
# Out:
# importing Jupyter notebook from ModelPlots.ipynb

# %% [markdown]
# ### Create all models now
#
# Pick colors from https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %%
vgg11 = models.vgg11(pretrained=True)

# %%
watcher = ww.WeightWatcher(model=vgg11) 
watcher.describe()
# Out:
# INFO:weightwatcher:
#
# python      version 3.9.5 (default, May 18 2021, 12:31:01)
# [Clang 10.0.0 ]
# numpy       version 1.19.5
# tensforflow version 2.5.0
# keras       version 2.5.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'ww2x': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'layers': []}
# INFO:weightwatcher:Saving all images to ww-img
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': False, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'ww2x': False, 'min_evals': 0, 'max_evals': None, 'plot': False, 'mp_fit': False, 'layers': []}
# INFO:weightwatcher:Saving all images to ww-img
# ...

# %% [markdown]
# ### Run WeightWatcher on VGG11

# %%
watcher = ww.WeightWatcher(model=vgg11) 
details = watcher.analyze( plot=True, mp_fit=True,  randomize=True,  ww2x=False)
# Out:
# INFO:weightwatcher:
#
# python      version 3.9.5 (default, May 18 2021, 12:31:01)
# [Clang 10.0.0 ]
# numpy       version 1.19.5
# tensforflow version 2.5.0
# keras       version 2.5.0
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': True, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'ww2x': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': True, 'layers': []}
# INFO:weightwatcher:Saving all images to ww-img
# INFO:weightwatcher:params {'glorot_fix': False, 'normalize': False, 'conv2d_norm': True, 'randomize': True, 'savedir': 'ww-img', 'savefig': 'ww-img', 'rescale': True, 'deltaEs': False, 'intra': False, 'channels': None, 'conv2d_fft': False, 'ww2x': False, 'min_evals': 0, 'max_evals': None, 'plot': True, 'mp_fit': True, 'layers': []}
# INFO:weightwatcher:Saving all images to ww-img
# ...

# %% [markdown]
# ### Analyze Layer 8 and Random Matrix Directly

# %%
watcher = ww.WeightWatcher(model=vgg11)

# %% [markdown]
# ### Fit ESD to MP

# %%
# %run weightwatcher/RMT_Util.py

# %%
layer_id = 8

details = watcher.describe(model=vgg11, layers=[layer_id])
display(details)

evals = watcher.get_ESD(model=vgg11, layer=layer_id, random=True)

N = int(details.N.values[0])
M = int(details.M.values[0])
Q = N/M

for rf, col in zip([int(details.rf.values[0]), 1.0],['purple', 'blue']):
    Wnorm = np.sqrt(np.sum(evals))
    Wscale = np.sqrt(N*rf)/Wnorm

    to_plot = (Wscale*Wscale)*evals

    bw = 0.1 
    s1, f1 = fit_density_with_range(to_plot, Q, bw = bw)
    sigma_mp = s1

    print("RF {} residual = {:0.2f} Wscale {:0.2g}".format(rf, f1, Wscale))
    title = "VGG11 Layer {} Random".format(layer_id)

    plot_density_and_fit(model=None, eigenvalues=to_plot, layer_name=title, layer_id=layer_id,
                          Q=Q, num_spikes=0, sigma=s1, verbose = False, plot=True, color=col)
    plt.show()

# %%
details
