# %% [markdown]
# # WWVGG19-Test

# %%
# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext watermark
# %watermark
# Out:
# 2021-10-12T13:21:43-07:00
#
# CPython 3.8.5
# IPython 7.18.1
#
# compiler   : Clang 10.0.0
# system     : Darwin
# release    : 17.7.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 12
# interpreter: 64bit

# %% [markdown]
# ### Import WeightWatcher
#
# set custom Logging at WARN Level

# %%
import logging

import weightwatcher as ww
import torchvision.models as models

logger = logging.getLogger(ww.__name__)
logger.setLevel(logging.WARNING)

ww.__version__
# Out:
# '0.5.4'

# %% [markdown]
# ###  How to create a WWLayerIterator

# %%
modelname = 'VGG19'
model = models.vgg19(pretrained=True)
watcher = ww.WeightWatcher(model=model)

# %% [markdown]
# #### IDK why the ints are floats

# %%
details =  watcher.describe(model=model)
details
# Out:
#    layer_id  name       M        N         layer_type  num_evals   rf
# 0         2  None     3.0     64.0  LAYER_TYPE.CONV2D       27.0  9.0
# 1         4  None    64.0     64.0  LAYER_TYPE.CONV2D      576.0  9.0
# 2         7  None    64.0    128.0  LAYER_TYPE.CONV2D      576.0  9.0
# 3         9  None   128.0    128.0  LAYER_TYPE.CONV2D     1152.0  9.0
# 4        12  None   128.0    256.0  LAYER_TYPE.CONV2D     1152.0  9.0
# 5        14  None   256.0    256.0  LAYER_TYPE.CONV2D     2304.0  9.0
# 6        16  None   256.0    256.0  LAYER_TYPE.CONV2D     2304.0  9.0
# 7        18  None   256.0    256.0  LAYER_TYPE.CONV2D     2304.0  9.0
# 8        21  None   256.0    512.0  LAYER_TYPE.CONV2D     2304.0  9.0
# 9        23  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 10       25  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 11       27  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 12       30  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 13       32  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 14       34  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 15       36  None   512.0    512.0  LAYER_TYPE.CONV2D     4608.0  9.0
# 16       41  None  4096.0  25088.0   LAYER_TYPE.DENSE     4096.0  1.0
# 17       44  None  4096.0   4096.0   LAYER_TYPE.DENSE     4096.0  1.0
# 18       47  None  1000.0   4096.0   LAYER_TYPE.DENSE     1000.0  1.0

# %%
details =  watcher.analyze(model=model, plot=True, randomize=True)
details
# Out:
# Assuming nested distributions
# Assuming nested distributions
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# Assuming nested distributions
# 'nan' in fit cumulative distribution values.
# Likely underflow or overflow error: the optimal fit for this distribution gives values that are so extreme that we lack the numerical precision to calculate them.
# Assuming nested distributions
# Assuming nested distributions
# Assuming nested distributions
# Assuming nested distributions
# Assuming nested distributions
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a13c2978acf0> in <module>
# ----> 1 details =  watcher.analyze(model=model, plot=True, randomize=True)
#       2 details
#
# ~/Desktop/work/weightwatcher/github/WeightWatcher/weightwatcher/weightwatcher.py in analyze(self, model, layers, min_evals, max_evals, min_size, max_size, normalize, glorot_fix, plot, randomize, savefig, mp_fit, conv2d_fft, conv2d_norm, ww2x, deltas, intra, vectors, channels, stacked, fix_fingers)
#    1584
#    1585                 if ww_layer.evals is not None:
# -> 1586                     self.apply_fit_powerlaw(ww_layer, params)
#    1587                     if params['mp_fit']:
#    1588                         logger.debug("MP Fitting Layer: {} {} ".format(ww_layer.layer_id, ww_layer.name))
#
# ~/Desktop/work/weightwatcher/github/WeightWatcher/weightwatcher/weightwatcher.py in apply_fit_powerlaw(self, ww_layer, params)
#    1395         ff =  params['fix_fingers']
#    1396         layer_name = "Layer {}".format(layer_id)
# -> 1397         alpha, xmin, xmax, D, sigma, num_pl_spikes, best_fit = self.fit_powerlaw(evals, xmin=xmin, xmax=xmax, plot=plot, layer_name=layer_name, layer_id=layer_id, sample=sample, sample_size=sample_size, savedir=savedir, fix_fingers=ff)
#    1398
#    1399         ww_layer.add_column('alpha', alpha)
#
# ~/Desktop/work/weightwatcher/github/WeightWatcher/weightwatcher/weightwatcher.py in fit_powerlaw(self, evals, xmin, xmax, plot, layer_name, layer_id, sample, sample_size, savedir, savefig, svd_method, thresh, fix_fingers)
#    1950         if xmin == XMAX.AUTO  or xmin is None:
#    1951             nz_evals = evals[evals > thresh]
# -> 1952             fit = powerlaw.Fit(nz_evals, xmax=xmax, verbose=False)
#    1953         elif xmin == XMAX.PEAK :
#    1954             nz_evals = evals[evals > thresh]
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in __init__(self, data, discrete, xmin, xmax, verbose, fit_method, estimate_discrete, discrete_approximation, sigma_threshold, parameter_range, fit_optimizer, xmin_distance, **kwargs)
#     135             if verbose:
#     136                 print("Calculating best minimal value for power law fit", file=sys.stderr)
# --> 137             self.find_xmin()
#     138
#     139         self.data = self.data[self.data>=self.xmin]
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in find_xmin(self, xmin_distance)
#     234             return getattr(pl, xmin_distance), pl.alpha, pl.sigma, pl.in_range()
#     235
# --> 236         fits = asarray(list(map(fit_function, xmins)))
#     237         # logging.warning(fits.shape)
#     238         setattr(self, xmin_distance+'s', fits[:,0])
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in fit_function(xmin)
#     224
#     225         def fit_function(xmin):
# --> 226             pl = Power_Law(xmin=xmin,
#     227                            xmax=self.xmax,
#     228                            discrete=self.discrete,
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in __init__(self, estimate_discrete, **kwargs)
#    1111     def __init__(self, estimate_discrete=True, **kwargs):
#    1112         self.estimate_discrete = estimate_discrete
# -> 1113         Distribution.__init__(self, **kwargs)
#    1114
#    1115     def parameters(self, params):
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in __init__(self, xmin, xmax, discrete, fit_method, data, parameters, parameter_range, initial_parameters, discrete_approximation, parent_Fit, **kwargs)
#     608
#     609         if (data is not None) and not (parameter_range and self.parent_Fit):
# --> 610             self.fit(data)
#     611
#     612
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in fit(self, data)
#    1149             self.KS(data)
#    1150         else:
# -> 1151             Distribution.fit(self, data, suppress_output=True)
#    1152
#    1153         if not self.in_range():
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in fit(self, data, suppress_output)
#     631         from scipy.optimize import fmin
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
# --> 633             fmin(
#     634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     441             'initial_simplex': initial_simplex}
#     442
# --> 443     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     444     if full_output:
#     445         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     631                     # Perform an inside contraction
#     632                     xcc = (1 - psi) * xbar + psi * sim[-1]
# --> 633                     fxcc = func(xcc)
#     634
#     635                     if fxcc < fsim[-1]:
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in <lambda>(params)
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
#     633             fmin(
# --> 634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
#
# ~/anaconda3/envs/ww0.5/lib/python3.8/site-packages/powerlaw.py in fit_function(params)
#     623             def fit_function(params):
#     624                 self.parameters(params)
# --> 625                 return -sum(self.loglikelihoods(data))
#     626         elif self.fit_method=='KS':
#     627             def fit_function(params):
#
# KeyboardInterrupt:

# %%
details.rand_distance.hist(bins=50)
plt.title("{}:   distance(X, rand(X))".format(modelname))

# %%
details[['alpha', 'rand_distance']].plot.scatter(x='alpha', y='rand_distance')
plt.title("{}: alpha vs Dist(X,rand(X))".format(modelname))

# %%
da = details[details.alpha<5]
da[['alpha', 'rand_distance']].plot.scatter(x='alpha', y='rand_distance')
plt.title("{}: Alpha vs Dist(X,rand(X)), alpha < 5".format(modelname))

# %%
details

# %%
plt.hist(details.alpha, bins=30);
plt.title("{} default".format(modelname))
plt.xlabel("alpha")

# %%
import powerlaw

def plot_loghist(x, bins, xmin):
    hist, bins = np.histogram(x, bins=bins)
    logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
    plt.hist(x, bins=logbins, density=True)

    if xmin:
        plt.axvline(xmin, color='r', label=r'$\lambda_{min}$')

    plt.xscale('log')

# %%
layer_id = 9
esd = watcher.get_ESD(layer=layer_id)
esd = esd[esd>0.01]
results = powerlaw.Fit(esd, xmax=np.max(esd))
plot_loghist(esd, bins=100, xmin=results.xmin);
title = "{} Layer {} ESD".format(modelname, layer_id)
title += "   alpha={:0.3} D={:0.3}".format(results.alpha, results.D)
plt.title(title)
plt.legend()
# Out:
# Calculating best minimal value for power law fit

# %%
N = int(len(esd)/2)
for idx in tqdm(range(0,N,1)):
    if idx == 0:
        xmax = np.max(esd)
    else:
        xmax = np.max(esd[-idx])
        
    results = powerlaw.Fit(esd, xmax=xmax)
    alpha, D = results.alpha, results.D
    # stop when distribtion becomes power law
    R, p = results.distribution_compare('truncated_power_law', 'power_law', normalized_ratio=True)
    if R > 0.0:
        print(idx, alpha, D, R,p)
        
        plot_loghist(esd, bins=100, xmin=results.xmin);
        title = "{} Layer {} ESD".format(modelname, layer_id)
        title += "   alpha={:0.3} D={:0.3}".format(results.alpha, results.D)
        plt.title(title)
        plt.legend()
        break
# Out:
#   0%|          | 0/441 [00:00<?, ?it/s]Calculating best minimal value for power law fit
# Assuming nested distributions
#   0%|          | 1/441 [00:02<18:07,  2.47s/it]Calculating best minimal value for power law fit
# Assuming nested distributions
#   0%|          | 2/441 [00:04<18:06,  2.47s/it]Calculating best minimal value for power law fit
# Assuming nested distributions
#   0%|          | 2/441 [00:07<27:51,  3.81s/it]
# 2 1.887176475026711 0.14655780126237317 7.716794687711722 0.0
